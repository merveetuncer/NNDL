# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ***1)DATASET***

# %%
# !wget -P regression_dataset https://gitlab.dei.unipd.it/michieli/nnld-2021-22-lab-resources/-/raw/main/homework1/train_data.csv
# !wget -P regression_dataset https://gitlab.dei.unipd.it/michieli/nnld-2021-22-lab-resources/-/raw/main/homework1/test_data.csv
# Out:
# --2021-12-29 13:45:27--  https://gitlab.dei.unipd.it/michieli/nnld-2021-22-lab-resources/-/raw/main/homework1/train_data.csv
# Resolving gitlab.dei.unipd.it (gitlab.dei.unipd.it)... 147.162.2.85
# Connecting to gitlab.dei.unipd.it (gitlab.dei.unipd.it)|147.162.2.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3776 (3.7K) [text/plain]
# Saving to: ‘regression_dataset/train_data.csv’
#
# train_data.csv      100%[===================>]   3.69K  --.-KB/s    in 0s
#
# 2021-12-29 13:45:28 (58.3 MB/s) - ‘regression_dataset/train_data.csv’ saved [3776/3776]
#
# --2021-12-29 13:45:28--  https://gitlab.dei.unipd.it/michieli/nnld-2021-22-lab-resources/-/raw/main/homework1/test_data.csv
# Resolving gitlab.dei.unipd.it (gitlab.dei.unipd.it)... 147.162.2.85
# Connecting to gitlab.dei.unipd.it (gitlab.dei.unipd.it)|147.162.2.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3788 (3.7K) [text/plain]
# Saving to: ‘regression_dataset/test_data.csv’
#
# test_data.csv       100%[===================>]   3.70K  --.-KB/s    in 0s
#
# 2021-12-29 13:45:29 (58.0 MB/s) - ‘regression_dataset/test_data.csv’ saved [3788/3788]

# %%
#Load train data
train_df = pd.read_csv('regression_dataset/train_data.csv')

# %%
#Load test data
test_df = pd.read_csv('regression_dataset/test_data.csv')

# %%
#describe train_data
train_df .describe()
# Out:
#             input       label
# count  100.000000  100.000000
# mean     0.535661    2.826761
# std      3.511726    1.962990
# min     -4.915863   -3.742970
# 25%     -3.255942    1.677844
# 50%      0.037716    2.663394
# 75%      4.143882    3.727911
# max      4.977516    7.199304

# %%
fig = plt.figure(figsize=(10,8))
plt.scatter(train_df.input, train_df.label, label='Training points')
plt.xlabel('input')
plt.ylabel('label')
plt.legend()
plt.show()

# %%
#describe test_data
test_df.describe()
# Out:
#             input       label
# count  100.000000  100.000000
# mean    -0.088111    2.572386
# std      2.924814    1.697217
# min     -4.999868   -2.999869
# 25%     -2.733220    1.781779
# 50%      0.029972    2.715547
# 75%      2.208296    3.767334
# max      4.894875    6.335996

# %%
train_df=train_df.values
test_df=test_df.values

# %%
#Prepare X_train, y_train, X_test, y_test
X_train=train_df[:,0]
y_train=train_df[:,1]

X_test=test_df[:,0]
y_test=test_df[:,1]

# %%
#convert to Pytorch tensor for train data
X_train=np.expand_dims(X_train, axis=1)
y_train=np.expand_dims(y_train, axis=1)
X_train=torch.from_numpy(X_train).float()
y_train=torch.from_numpy(y_train).float()

# %%
#convert to Pytorch tensor for test data
X_test=np.expand_dims(X_test, axis=1)
y_test=np.expand_dims(y_test, axis=1)
X_test=torch.from_numpy(X_test).float()
y_test=torch.from_numpy(y_test).float()

# %%
print(X_train.size())
print(min(X_train),max(X_train))
print(min(y_train),max(y_train))
print(X_test.size())
print(min(X_test),max(X_test))
print(min(y_test),max(y_test))
# Out:
# torch.Size([100, 1])
# tensor([-4.9159]) tensor([4.9775])
# tensor([-3.7430]) tensor([7.1993])
# torch.Size([100, 1])
# tensor([-4.9999]) tensor([4.8949])
# tensor([-2.9999]) tensor([6.3360])

# %% [markdown]
# **2)MODEL**

# %%
class RegNet(nn.Module):
    
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()
        
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.sig = nn.Sigmoid()
        self.relu= nn.ReLU()
        
        self.name="RegNet"

        print('Network initialized')
        
    def forward(self, x, additional_out=False):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.out(x)  # Non activaction function on last layer because the output can be greater than 1
        return x

# %% [markdown]
# **3)TRAINING**

# %%
# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Training device: {device}")
# Out:
# Training device: cuda

# %%
# Define the loss function
loss_function = nn.MSELoss()

# %%
# !pip install skorch
# Out:
# Collecting skorch
#   Downloading skorch-0.11.0-py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 5.2 MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.4.1)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.7/dist-packages (from skorch) (4.62.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from skorch) (0.8.9)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->skorch) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->skorch) (3.0.0)
# Installing collected packages: skorch
# Successfully installed skorch-0.11.0

# %%
from skorch.callbacks import EarlyStopping

my_early = EarlyStopping(
    monitor='valid_loss',
    patience=500,
    threshold=0.0001,
    threshold_mode='rel',
    lower_is_better=True)

# %% [markdown]
# **3.1) Grid Search**

# %%
from skorch import NeuralNetRegressor

net = NeuralNetRegressor(
    module=RegNet,
    module__Ni= 1,
    module__Nh1 = 32,
    module__Nh2 = 32,
    module__No = 1,
    max_epochs=3000,
    
    device=device,  # uncomment this to train with CUDA
    optimizer = optim.Adam,
    optimizer__lr=0.001,
    optimizer__weight_decay=1e-5, #L2 norm
    criterion=nn.MSELoss,
    callbacks = [my_early],
    verbose=0
)

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'module__Nh1': [8,16,32,48],
    'module__Nh2': [8,16,32,48],
    'max_epochs': [1500],
    'optimizer__lr':[0.1, 0.01, 0.001],
    'optimizer__weight_decay':[1e-3,1e-4,1e-5] #L2 norm,
}

gs = GridSearchCV(net, params, refit=True, cv=3, scoring="neg_mean_squared_error",verbose=10)

gs.fit(X_train, y_train)

print(gs.best_score_, gs.best_params_)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV 1/3; 1/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 1/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-7.341 total time=  14.0s
# [CV 2/3; 1/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 1/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.442 total time=   6.9s
# [CV 3/3; 1/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 1/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-9.232 total time=   2.9s
# [CV 1/3; 2/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 2/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-374.401 total time=   3.2s
# [CV 2/3; 2/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 2/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.383 total time=   6.5s
# [CV 3/3; 2/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 2/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-15.813 total time=  11.2s
# [CV 1/3; 3/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 3/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-100.420 total time=   3.0s
# [CV 2/3; 3/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 3/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.403 total time=   4.1s
# [CV 3/3; 3/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 3/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-12.553 total time=   7.3s
# [CV 1/3; 4/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 4/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-42.679 total time=   3.2s
# [CV 2/3; 4/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 4/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-0.285 total time=   8.3s
# [CV 3/3; 4/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 4/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-9.097 total time=   3.6s
# [CV 1/3; 5/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 5/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-1525.735 total time=   3.2s
# [CV 2/3; 5/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 5/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.477 total time=   6.5s
# [CV 3/3; 5/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 5/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-10.794 total time=   6.2s
# [CV 1/3; 6/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 6/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-190.046 total time=   3.4s
# [CV 2/3; 6/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 6/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-0.404 total time=   6.7s
# [CV 3/3; 6/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 6/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-12.069 total time=   5.9s
# [CV 1/3; 7/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 7/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-62.899 total time=   5.6s
# [CV 2/3; 7/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 7/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-1.328 total time=   9.6s
# [CV 3/3; 7/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 7/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-11.920 total time=   8.5s
# [CV 1/3; 8/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 8/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-70.958 total time=   7.5s
# [CV 2/3; 8/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 8/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-3.116 total time=   8.5s
# [CV 3/3; 8/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 8/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-11.647 total time=   8.5s
# [CV 1/3; 9/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 9/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-3.753 total time=   4.2s
# [CV 2/3; 9/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 9/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-1.384 total time=   8.6s
# [CV 3/3; 9/144] START max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 9/144] END max_epochs=1500, module__Nh1=8, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-11.071 total time=   8.6s
# [CV 1/3; 10/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 10/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-43.800 total time=   2.9s
# [CV 2/3; 10/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 10/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.412 total time=   3.0s
# [CV 3/3; 10/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 10/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-11.353 total time=   3.0s
# [CV 1/3; 11/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 11/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-3.889 total time=   2.9s
# [CV 2/3; 11/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 11/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.432 total time=   3.2s
# [CV 3/3; 11/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 11/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-11.850 total time=   5.5s
# [CV 1/3; 12/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 12/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-227.033 total time=   3.0s
# [CV 2/3; 12/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 12/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.666 total time=   3.7s
# [CV 3/3; 12/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 12/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-12.126 total time=   6.9s
# [CV 1/3; 13/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 13/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-49.190 total time=   4.8s
# [CV 2/3; 13/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 13/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-0.328 total time=   4.8s
# [CV 3/3; 13/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 13/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-6.716 total time=   8.2s
# [CV 1/3; 14/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 14/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-70.903 total time=   2.9s
# [CV 2/3; 14/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 14/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.405 total time=   8.4s
# [CV 3/3; 14/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 14/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-10.104 total time=   3.5s
# [CV 1/3; 15/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 15/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-51.446 total time=   4.0s
# [CV 2/3; 15/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 15/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-1.135 total time=   8.3s
# [CV 3/3; 15/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 15/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-9.743 total time=   3.2s
# [CV 1/3; 16/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 16/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-80.209 total time=   7.0s
# [CV 2/3; 16/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 16/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-3.508 total time=   8.4s
# [CV 3/3; 16/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 16/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-12.642 total time=   8.4s
# [CV 1/3; 17/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 17/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-283.323 total time=   5.3s
# [CV 2/3; 17/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 17/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-0.315 total time=   8.3s
# [CV 3/3; 17/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 17/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-7.779 total time=   8.4s
# [CV 1/3; 18/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 18/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-10.728 total time=   8.1s
# [CV 2/3; 18/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 18/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-7.815 total time=   8.3s
# [CV 3/3; 18/144] START max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 18/144] END max_epochs=1500, module__Nh1=8, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-11.119 total time=   7.8s
# [CV 1/3; 19/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 19/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-42.093 total time=   2.8s
# [CV 2/3; 19/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 19/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.393 total time=   3.1s
# [CV 3/3; 19/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 19/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-8.467 total time=   3.6s
# [CV 1/3; 20/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 20/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-58.566 total time=   2.9s
# [CV 2/3; 20/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 20/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.450 total time=   3.1s
# [CV 3/3; 20/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 20/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-11.503 total time=   3.9s
# [CV 1/3; 21/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 21/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-100.725 total time=   2.9s
# [CV 2/3; 21/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 21/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.373 total time=   3.5s
# [CV 3/3; 21/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 21/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-11.562 total time=   3.3s
# [CV 1/3; 22/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 22/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-40.122 total time=   3.6s
# [CV 2/3; 22/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 22/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-0.434 total time=   5.8s
# [CV 3/3; 22/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 22/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-7.321 total time=   8.2s
# [CV 1/3; 23/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 23/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-7.394 total time=   8.2s
# [CV 2/3; 23/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 23/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.911 total time=   4.1s
# [CV 3/3; 23/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 23/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-9.857 total time=   7.4s
# [CV 1/3; 24/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 24/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-219.030 total time=   3.2s
# [CV 2/3; 24/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 24/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-0.600 total time=   5.9s
# [CV 3/3; 24/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 24/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-6.343 total time=   6.8s
# [CV 1/3; 25/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 25/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-45.849 total time=   6.0s
# [CV 2/3; 25/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 25/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-1.657 total time=   8.4s
# [CV 3/3; 25/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 25/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-8.036 total time=   8.5s
# [CV 1/3; 26/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 26/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-79.596 total time=   5.4s
# [CV 2/3; 26/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 26/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-1.719 total time=   8.4s
# [CV 3/3; 26/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 26/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-9.290 total time=   8.4s
# [CV 1/3; 27/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 27/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-217.431 total time=   5.1s
# [CV 2/3; 27/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 27/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-0.741 total time=   8.4s
# [CV 3/3; 27/144] START max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 27/144] END max_epochs=1500, module__Nh1=8, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-11.991 total time=   8.5s
# [CV 1/3; 28/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 28/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-110.944 total time=   2.8s
# [CV 2/3; 28/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 28/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.386 total time=   5.2s
# [CV 3/3; 28/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 28/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-11.835 total time=   5.1s
# [CV 1/3; 29/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 29/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-2348.458 total time=   2.9s
# [CV 2/3; 29/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 29/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.448 total time=   3.0s
# [CV 3/3; 29/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 29/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-8.931 total time=   3.3s
# [CV 1/3; 30/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 30/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-23.938 total time=   2.9s
# [CV 2/3; 30/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 30/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.364 total time=   3.3s
# [CV 3/3; 30/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 30/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-12.317 total time=   4.7s
# [CV 1/3; 31/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 31/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-29.390 total time=   3.0s
# [CV 2/3; 31/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 31/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-1.495 total time=   4.2s
# [CV 3/3; 31/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 31/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-9.212 total time=   4.8s
# [CV 1/3; 32/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 32/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-2575.014 total time=   3.1s
# [CV 2/3; 32/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 32/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.472 total time=   8.3s
# [CV 3/3; 32/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 32/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-6.623 total time=   8.3s
# [CV 1/3; 33/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 33/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-82.302 total time=   2.9s
# [CV 2/3; 33/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 33/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-0.366 total time=   8.1s
# [CV 3/3; 33/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 33/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-11.981 total time=   6.2s
# [CV 1/3; 34/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 34/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-60.686 total time=   4.3s
# [CV 2/3; 34/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 34/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-3.669 total time=   8.4s
# [CV 3/3; 34/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 34/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-12.000 total time=   8.4s
# [CV 1/3; 35/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 35/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-89.385 total time=   4.0s
# [CV 2/3; 35/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 35/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-1.396 total time=   8.4s
# [CV 3/3; 35/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 35/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-13.661 total time=   8.4s
# [CV 1/3; 36/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 36/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-437.713 total time=   4.9s
# [CV 2/3; 36/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 36/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-2.216 total time=   7.7s
# [CV 3/3; 36/144] START max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 36/144] END max_epochs=1500, module__Nh1=8, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-7.198 total time=   8.4s
# [CV 1/3; 37/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 37/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-294.858 total time=   2.9s
# [CV 2/3; 37/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 37/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.376 total time=   4.5s
# [CV 3/3; 37/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 37/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-5.841 total time=   3.5s
# [CV 1/3; 38/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 38/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-2811.869 total time=   2.9s
# [CV 2/3; 38/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 38/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.365 total time=   4.2s
# [CV 3/3; 38/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 38/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-10.083 total time=   3.0s
# [CV 1/3; 39/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 39/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-9.427 total time=   3.1s
# [CV 2/3; 39/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 39/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.384 total time=   3.6s
# [CV 3/3; 39/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 39/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-13.071 total time=   6.4s
# [CV 1/3; 40/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 40/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-15.649 total time=   3.0s
# [CV 2/3; 40/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 40/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-0.373 total time=   7.5s
# [CV 3/3; 40/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 40/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-7.243 total time=   6.9s
# [CV 1/3; 41/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 41/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-63.168 total time=   5.0s
# [CV 2/3; 41/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 41/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.435 total time=   8.4s
# [CV 3/3; 41/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 41/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-12.725 total time=   8.3s
# [CV 1/3; 42/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 42/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-2570.981 total time=   2.9s
# [CV 2/3; 42/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 42/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-0.755 total time=   8.3s
# [CV 3/3; 42/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 42/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-6.951 total time=   7.0s
# [CV 1/3; 43/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 43/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-63.633 total time=   4.5s
# [CV 2/3; 43/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 43/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-0.996 total time=   8.0s
# [CV 3/3; 43/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 43/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-12.515 total time=   8.4s
# [CV 1/3; 44/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 44/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-68.550 total time=   6.0s
# [CV 2/3; 44/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 44/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-4.655 total time=   8.5s
# [CV 3/3; 44/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 44/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-11.815 total time=   8.4s
# [CV 1/3; 45/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 45/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-78.418 total time=   5.5s
# [CV 2/3; 45/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 45/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-1.238 total time=   8.4s
# [CV 3/3; 45/144] START max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 45/144] END max_epochs=1500, module__Nh1=16, module__Nh2=8, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-11.870 total time=   8.5s
# [CV 1/3; 46/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 46/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-239.495 total time=   3.2s
# [CV 2/3; 46/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 46/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.473 total time=   3.9s
# [CV 3/3; 46/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 46/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-12.477 total time=   5.2s
# [CV 1/3; 47/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 47/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-42.282 total time=   2.9s
# [CV 2/3; 47/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 47/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.333 total time=   3.8s
# [CV 3/3; 47/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 47/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-7.498 total time=   5.5s
# [CV 1/3; 48/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 48/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-5.506 total time=   2.8s
# [CV 2/3; 48/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 48/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.353 total time=   5.6s
# [CV 3/3; 48/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 48/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-6.424 total time=   4.2s
# [CV 1/3; 49/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 49/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-767.472 total time=   3.0s
# [CV 2/3; 49/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 49/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-0.307 total time=   6.3s
# [CV 3/3; 49/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 49/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-7.164 total time=   6.7s
# [CV 1/3; 50/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 50/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-2335.166 total time=   3.9s
# [CV 2/3; 50/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 50/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.454 total time=   7.2s
# [CV 3/3; 50/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 50/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-15.323 total time=   5.5s
# [CV 1/3; 51/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 51/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-1592.476 total time=   3.1s
# [CV 2/3; 51/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 51/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-1.247 total time=   4.9s
# [CV 3/3; 51/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 51/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-11.641 total time=   4.1s
# [CV 1/3; 52/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 52/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-58.930 total time=   5.0s
# [CV 2/3; 52/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 52/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-1.929 total time=   8.5s
# [CV 3/3; 52/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 52/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-9.062 total time=   8.1s
# [CV 1/3; 53/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 53/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-81.905 total time=   4.3s
# [CV 2/3; 53/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 53/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-1.104 total time=   8.5s
# [CV 3/3; 53/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 53/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-11.110 total time=   8.5s
# [CV 1/3; 54/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 54/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-126.404 total time=   4.8s
# [CV 2/3; 54/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 54/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-1.754 total time=   8.4s
# [CV 3/3; 54/144] START max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 54/144] END max_epochs=1500, module__Nh1=16, module__Nh2=16, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-12.386 total time=   8.5s
# [CV 1/3; 55/144] START max_epochs=1500, module__Nh1=16, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# ...
# Network initialized
# [CV 2/3; 127/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.361 total time=   7.6s
# [CV 3/3; 127/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 127/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-11.778 total time=   6.5s
# [CV 1/3; 128/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 128/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-12.361 total time=   2.8s
# [CV 2/3; 128/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 128/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.293 total time=   8.1s
# [CV 3/3; 128/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 128/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-11.230 total time=   3.4s
# [CV 1/3; 129/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 129/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-2259.960 total time=   2.7s
# [CV 2/3; 129/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 129/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.340 total time=   3.1s
# [CV 3/3; 129/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 129/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-12.261 total time=   8.0s
# [CV 1/3; 130/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 130/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-18.853 total time=   2.8s
# [CV 2/3; 130/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 130/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-0.384 total time=   8.0s
# [CV 3/3; 130/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 130/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-8.492 total time=   8.0s
# [CV 1/3; 131/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 131/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-6.963 total time=   2.7s
# [CV 2/3; 131/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 131/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.326 total time=   7.4s
# [CV 3/3; 131/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 131/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-7.472 total time=   5.3s
# [CV 1/3; 132/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 132/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-2641.189 total time=   2.8s
# [CV 2/3; 132/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 132/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-0.793 total time=   4.6s
# [CV 3/3; 132/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 132/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-5.966 total time=   6.9s
# [CV 1/3; 133/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 133/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-211.301 total time=   3.9s
# [CV 2/3; 133/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 133/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-0.904 total time=   8.2s
# [CV 3/3; 133/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 133/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-5.621 total time=   8.3s
# [CV 1/3; 134/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 134/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-200.395 total time=   3.6s
# [CV 2/3; 134/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 134/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-0.932 total time=   7.3s
# [CV 3/3; 134/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 134/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-6.662 total time=   8.2s
# [CV 1/3; 135/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 135/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-21.760 total time=   3.7s
# [CV 2/3; 135/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 135/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-1.282 total time=   8.2s
# [CV 3/3; 135/144] START max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 135/144] END max_epochs=1500, module__Nh1=48, module__Nh2=32, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-8.654 total time=   8.2s
# [CV 1/3; 136/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 136/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-573.763 total time=   2.8s
# [CV 2/3; 136/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 136/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-0.373 total time=   3.3s
# [CV 3/3; 136/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 136/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.001;, score=-9.276 total time=   3.0s
# [CV 1/3; 137/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 137/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-2613.618 total time=   2.7s
# [CV 2/3; 137/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 137/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-0.353 total time=   5.9s
# [CV 3/3; 137/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 137/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=0.0001;, score=-9.176 total time=   2.8s
# [CV 1/3; 138/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 138/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-143.957 total time=   2.8s
# [CV 2/3; 138/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 138/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-0.465 total time=   4.6s
# [CV 3/3; 138/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 138/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.1, optimizer__weight_decay=1e-05;, score=-6.948 total time=   6.6s
# [CV 1/3; 139/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 139/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-23.845 total time=   2.9s
# [CV 2/3; 139/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 139/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-0.575 total time=   7.8s
# [CV 3/3; 139/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 139/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.001;, score=-7.799 total time=   4.2s
# [CV 1/3; 140/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 140/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-2017.339 total time=   2.7s
# [CV 2/3; 140/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 140/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-0.563 total time=   4.8s
# [CV 3/3; 140/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 140/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=0.0001;, score=-6.522 total time=   6.1s
# [CV 1/3; 141/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 141/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-2650.068 total time=   2.9s
# [CV 2/3; 141/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 141/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-0.585 total time=   6.6s
# [CV 3/3; 141/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 141/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.01, optimizer__weight_decay=1e-05;, score=-6.425 total time=   7.4s
# [CV 1/3; 142/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 1/3; 142/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-81.402 total time=   3.2s
# [CV 2/3; 142/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 2/3; 142/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-0.712 total time=   8.3s
# [CV 3/3; 142/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001
# Network initialized
# [CV 3/3; 142/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.001;, score=-9.975 total time=   8.3s
# [CV 1/3; 143/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 1/3; 143/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-717.122 total time=   3.4s
# [CV 2/3; 143/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 2/3; 143/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-0.983 total time=   8.2s
# [CV 3/3; 143/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001
# Network initialized
# [CV 3/3; 143/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=0.0001;, score=-8.580 total time=   8.4s
# [CV 1/3; 144/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 1/3; 144/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-286.531 total time=   4.0s
# [CV 2/3; 144/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 2/3; 144/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-1.642 total time=   8.2s
# [CV 3/3; 144/144] START max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05
# Network initialized
# [CV 3/3; 144/144] END max_epochs=1500, module__Nh1=48, module__Nh2=48, optimizer__lr=0.001, optimizer__weight_decay=1e-05;, score=-7.887 total time=   8.2s
# Network initialized
# -3.855021516482035 {'max_epochs': 1500, 'module__Nh1': 16, 'module__Nh2': 48, 'optimizer__lr': 0.1, 'optimizer__weight_decay': 0.001}

# %%
net=gs.best_estimator_

# %%
net
# Out:
# <class 'skorch.regressor.NeuralNetRegressor'>[initialized](
#   module_=RegNet(
#     (fc1): Linear(in_features=1, out_features=16, bias=True)
#     (fc2): Linear(in_features=16, out_features=48, bias=True)
#     (out): Linear(in_features=48, out_features=1, bias=True)
#     (sig): Sigmoid()
#     (relu): ReLU()
#   ),
# )

# %%
 #best score for GridSearchCV
 #{'max_epochs': 1500, 'module__Nh1': 16, 'module__Nh2': 48, 'optimizer__lr': 0.1, 'optimizer__weight_decay': 0.001}

# %%
 #training
net.fit(X_train, y_train)
# Out:
# Network initialized
# <class 'skorch.regressor.NeuralNetRegressor'>[initialized](
#   module_=RegNet(
#     (fc1): Linear(in_features=1, out_features=16, bias=True)
#     (fc2): Linear(in_features=16, out_features=48, bias=True)
#     (out): Linear(in_features=48, out_features=1, bias=True)
#     (sig): Sigmoid()
#     (relu): ReLU()
#   ),
# )

# %%
import datetime
save_name="Regression_"+datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")

# get train losses from all epochs, a list of floats
history = net.history
train_loss_log=history[:, 'train_loss']
val_loss_log=history[:, 'valid_loss']

# Plot losses
plt.figure(figsize=(12,8))
plt.plot(train_loss_log)
plt.plot(val_loss_log)
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train loss', 'Validation loss'], loc='upper right')
plt.savefig("models/"+save_name+"_Losses", dpi=400)
plt.show()

# %%
y_pred = net.predict(X_test)
y_pred = torch.from_numpy(y_pred).float()

test_loss = loss_function(y_pred, y_test)
print(f"TEST LOSS: {test_loss}")
# Out:
# TEST LOSS: 0.14488697052001953

# %%
#Plot Test points vs Prdicted points
zipped_lists = zip(X_test, y_pred)
sorted_pairs = sorted(zipped_lists)

tuples = zip(*sorted_pairs)
X, y = [ list(tuple) for tuple in  tuples]

plt.figure(figsize=(12,8))
plt.plot(X_test, y_test, color='r', ls='', marker='.')
plt.plot(X, y, color='g', ls='--')
plt.title('Test points vs Predicted Points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend(['Test data points', 'Predictions'], loc='upper left')
plt.savefig("models/"+save_name+"_Predictions", dpi=400)
plt.show()

# %%
#Train Loss
train_loss=train_loss_log[-1]

#Val loss
val_loss=val_loss_log[-1]

print("Train Loss:\t",round(train_loss,3))
print("Val Loss:\t",round(val_loss,3))
print("Test Loss:\t",round(float(test_loss),3))
# Out:
# Train Loss:	 0.199
# Val Loss:	 0.493
# Test Loss:	 0.145

# %%
#Saving the whole model
import pickle
with open("models/"+save_name+".pkl", 'wb') as f:
    pickle.dump(net, f)
    
#Load the model
#with open(file_name, 'rb') as f:
#    new_net = pickle.load(f)

#Save Metrics to File
f = open("models/"+save_name+"_Metrics.txt", "a")
f.write('Train loss:\t'+ str(round(train_loss,3))+ "\n")
f.write('Val loss:\t'+ str(round(val_loss,3))+ "\n")
f.write('Test loss:\t'+ str(round(float(test_loss),3))+ "\n")
f.close()

# %%
#Access network parameters
my_best_net = net.module_

#First hidden Layer
h1_w = my_best_net.fc1.weight.data.cpu().numpy()
h1_b = my_best_net.fc1.bias.data.cpu().numpy()

#Second hidden Layer
h2_w = my_best_net.fc2.weight.data.cpu().numpy()
h2_b = my_best_net.fc2.bias.data.cpu().numpy()

# Output layer
out_w = my_best_net.out.weight.data.cpu().numpy()
out_b = my_best_net.out.bias.data.cpu().numpy()

# %%
# Weights histogram
fig, axs = plt.subplots(3, 1, figsize=(12,8))
axs[0].hist(h1_w.flatten(), 50)
axs[0].set_title('First hidden layer weights')
axs[1].hist(h2_w.flatten(), 50)
axs[1].set_title('Second hidden layer weights')
axs[2].hist(out_w.flatten(), 50)
axs[2].set_title('Output layer weights')
[ax.grid() for ax in axs]
plt.tight_layout()
plt.savefig("models/"+save_name+"_Weights-histogram", dpi=400)
plt.show()

# %%
def get_activation(layer, input, output):
    global activation
    activation = torch.sigmoid(output)
    
### Register hook
net=my_best_net
hook_handle = net.fc2.register_forward_hook(get_activation)

### Analyze activations
net = net.to(device)
net.eval()
with torch.no_grad():
    x1 = torch.tensor([0.1]).float().to(device)
    y1 = net(x1)
    z1 = activation
    x2 = torch.tensor([0.9]).float().to(device)
    y2 = net(x2)
    z2 = activation
    x3 = torch.tensor([2.5]).float().to(device)
    y3 = net(x3)
    z3 = activation

### Remove hook
hook_handle.remove()

### Plot activations
fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1.cpu().numpy(), use_line_collection=True)
axs[0].set_title('Last layer activations for input x=%.2f' % x1)
axs[1].stem(z2.cpu().numpy(), use_line_collection=True)
axs[1].set_title('Last layer activations for input x=%.2f' % x2)
axs[2].stem(z3.cpu().numpy(), use_line_collection=True)
axs[2].set_title('Last layer activations for input x=%.2f' % x3)
plt.tight_layout()
plt.savefig("models/"+save_name+"_Activations", dpi=400)
plt.show()
